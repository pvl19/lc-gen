# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import astroquery.gaia as gaia

# %% [markdown]
# ### Load data

# %%
data = pd.read_csv('/Users/philvanlane/Documents/lc_ae/data/TIC_cf_data_ext.csv')
data.keys()
# Out:
# Index(['GaiaDR3_ID', 'TIC_ID', 'Prot', 'dr3_parallax_zpt_corrected',
#        'parallax_error', 'teff_gspphot', 'G_0', 'e_G_0', 'BP_0', 'e_BP_0',
#        'RP_0', 'e_RP_0', 'BPRP0', 'e_BPRP0', 'age_Myr'],
#       dtype='object')

# %% [markdown]
# ### Plot Coverage

# %% [markdown]
# #### BPRP vs. G

# %%
plt.scatter(data['BPRP0'], data['G_0'], s=1, alpha=0.5)

plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# #### T_eff vs. G

# %%
plt.scatter(data['teff_gspphot'], data['G_0'], s=1, alpha=0.5)

plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.xlim(8000,2000)
plt.show()

# %% [markdown]
# #### Prot vs. BPRP

# %%
plt.scatter(data['BPRP0'], data['Prot'], s=1, alpha=0.5)

plt.yscale('log')
plt.show()
