# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Charter", "Bitstream Charter"],
    "font.style": "normal",
})

# %% [markdown]
# ### Plot losses of models

# %%
base_model_folder = "/Users/philvanlane/Documents/lc_ae/output/slurm/46126529-lcgen-baseline-flux-only/"
xchannels_model_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46136856-lcgen-baseline-with-extra-channels/'
metadata_model_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46136813-lcgen-baseline-with-metadata/'
all_inputs_model_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46139530-lcgen-baseline-metadata-xchannels-ext/'
dense_k_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46224669-lcgen-ext-k-dense-small/'
fib_k_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46246499-lcgen-ext-k-fib-small/'
base_single_k_folder = '/Users/philvanlane/Documents/lc_ae/output/slurm/46275227-lcgen-base-single-k-cont/'

metadata_loss_values = data = np.load(metadata_model_folder + "losses_per_epoch.npz")
base_loss_values = data = np.load(base_model_folder + "losses_per_epoch.npz")
xchannels_loss_values = data = np.load(xchannels_model_folder + "losses_per_epoch.npz")
all_inputs_loss_values = data = np.load(all_inputs_model_folder + "losses_per_epoch.npz")
dense_k_loss_values = data = np.load(dense_k_folder + "losses_per_epoch.npz")
fib_k_loss_values = data = np.load(fib_k_folder + "losses_per_epoch.npz")
base_single_k_loss_values = data = np.load(base_single_k_folder + "losses_per_epoch.npz")

# %% [markdown]
# #### Plot

# %%
plt.figure(figsize=(10,5))

# plt.plot(base_loss_values['train_loss'],label = 'base model',color='black')
# plt.plot(base_loss_values['val_loss'],color='black',linestyle='--',label='validation loss')

# # plt.plot(xchannels_loss_values['train_loss'],label = 'xchannels model',color='blue')
# # plt.plot(xchannels_loss_values['val_loss'],color='blue',linestyle='--')

# # plt.plot(metadata_loss_values['train_loss'],label = 'metadata model',color='green')
# # plt.plot(metadata_loss_values['val_loss'],color='green',linestyle='--')

# plt.plot(all_inputs_loss_values['train_loss'],label = 'all inputs model',color='red')
# plt.plot(all_inputs_loss_values['val_loss'],color='red',linestyle='--')

# plt.plot(dense_k_loss_values['train_loss'],label = 'dense k model',color='orange')
# plt.plot(dense_k_loss_values['val_loss'],color='orange',linestyle='--')

# plt.plot(fib_k_loss_values['train_loss'],label = 'fib k model',color='blue')
# plt.plot(fib_k_loss_values['val_loss'],color='blue',linestyle='--')

plt.plot(base_single_k_loss_values['train_loss'],label = 'new baseline',color='purple')
plt.plot(base_single_k_loss_values['val_loss'],color='purple',linestyle='--',label='validation loss')

plt.scatter(16,1.165)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(base_loss_values['train_loss'],label = 'base model',color='black')
plt.plot(base_loss_values['val_loss'],color='black',linestyle='--',label='validation loss')

plt.plot(xchannels_loss_values['train_loss'],label = 'xchannels model',color='blue')
plt.plot(xchannels_loss_values['val_loss'],color='blue',linestyle='--')

plt.plot(metadata_loss_values['train_loss'],label = 'metadata model',color='green')
plt.plot(metadata_loss_values['val_loss'],color='green',linestyle='--')

plt.plot(all_inputs_loss_values['train_loss'],label = 'all inputs model',color='red')
plt.plot(all_inputs_loss_values['val_loss'],color='red',linestyle='--')

plt.ylim(1.1,1.3)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
